# %%
# body mass index
# input weight and height
height = input("enter height")
weight = input("enter weight")

BMI = float(weight) / (float(height) ** 2 )

print(BMI)
# Out:
# enter height1.81
# enter weight71
# 21.672110130948383

# %% [markdown]
# # Fundamentals of visualization
# ### Graphic system for R language
#
# ### " Codes to graphs"
# ### " Minds to page and plots"
#
# ## What is grammar of graphics?
# ### Major Parts:
# - Mapping (Data) which data where to print
# - Aesthetic (Color, Shape, Size)
# - Geometric (Objects: Line, Bar, Points, Box, Map)
#
# - May also contain minor parts-data on specific coordinates
# ---
#
# ### My theory as a datascientist
#
#
# ### "Work like an artist or be a copycat
# - Python libraries( Pandas, Numpy, Scipy, Matplotlib, Seaborn, Scikit-learn, statsmodel)
#
# ### Variable type matters
# - Type of visualization depends on the variable type
# - IMP (Dr Andrew Abela charts suggestion)
# #### categorical variables
# - Counts(plot type)
# - Male vs Female
# - True vs False
# - 0 vs 1
# - Yes vs No
#
# #### continous variables
# - Scatter plots
# - Statistical proportions (mean and their comaprison)
# ---
#
# ### THINK BEFORE YOU SPEAK!
# Think before you start
# - Generate a hypothesis
# - Find a story in your data
# - Clean/tidy up data
# - Remove duplicates
# - Handle missing values
# - Find a proper variable to drop duplicate in data
# -- Subset the data if required

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

titanic = sns.load_dataset("titanic")
sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic)
plt.show() # for printing in vs code

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
p1 = sns.countplot(x="alone", data=titanic, hue="class")
p1.set_title("Plot for counting")
plt.show()

# %%
g = sns.FacetGrid(titanic, row="sex", hue="alone")
g = g(g.map(plt.scatter, "age", "fare").add_legend())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [5], line 2
#       1 g = sns.FacetGrid(titanic, row="sex", hue="alone")
# ----> 2 g = g(g.map(plt.scatter, "age", "fare").add_legend())
#
# TypeError: 'FacetGrid' object is not callable
